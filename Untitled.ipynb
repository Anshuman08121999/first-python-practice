# %%
c = 10

# %%
type(c)
# Out:
# int

# %%
r = "anshu"

# %%
r
# Out:
# 'anshu'

# %%
type(r)
# Out:
# str

# %%
d = 7+7j

# %%
d
# Out:
# (7+7j)

# %%
type(d)
# Out:
# complex

# %%
P = "I love you"

# %%
type(P)
# Out:
# str

# %%
P
# Out:
# 'I love you'

# %%
g = True

# %%
type(g)
# Out:
# bool

# %%
c=12

# %%
c
# Out:
# 12

# %%
c1=5

# %%
c+c1
# Out:
# 17

# %%
a,b,c,d = 812199, "Ansh", 5+7j, False

# %%
d
# Out:
# False

# %%
a
# Out:
# 812199

# %%
c
# Out:
# (5+7j)

# %%
type(d)
# Out:
# bool

# %%
c
# Out:
# (5+7j)

# %%
c.imag
# Out:
# 7.0

# %%
c.real
# Out:
# 5.0

# %%
c.conjugate
# Out:
# <function complex.conjugate>

# %%
a="ansh"

# %%
a+'4'
# Out:
# 'ansh4'

# %%
a+str(4)
# Out:
# 'ansh4'

# %%
True+True+True
# Out:
# 3

# %%
True-False
# Out:
# 1

# %%
False-True-True
# Out:
# -2

# %%
8-False
# Out:
# 8

# %%
8-True+True
# Out:
# 8

# %%
8-True
# Out:
# 7

# %%
8-True+False
# Out:
# 7

# %%
-True+False
# Out:
# -1

# %%
a= 'true/false'

# %%
a
# Out:
# 'true/false'

# %%
a=input()
# Out:
# 500

# %%
b=100

# %%
a
# Out:
# '500'

# %%
int(a)+b
# Out:
# 600

# %%
int("500")
# Out:
# 500

# %%
str(500)
# Out:
# '500'

# %%
a=input()
# Out:
# Good luck

# %%
a
# Out:
# 'Good luck'

# %%
b=4

# %%
str(a)
# Out:
# 'Good luck'

# %%
a="ansh"

# %%
a=4

# %%
str(a)
# Out:
# 'ansh'

# %%
a+4
# Out:
# 8

# %%
a="ansh"

# %%
a+"4"
# Out:
# 'ansh4'

# %%
type(4)
# Out:
# int

# %%
type(a)
# Out:
# str

# %%
5+10j
# Out:
# (5+10j)

# %%
type(5+10J)
# Out:
# complex

# %%
5+10j-True
# Out:
# (4+10j)

# %%
10j.real
# Out:
# 0.0

# %%
10j.imag
# Out:
# 10.0

# %%
5+10j/5
# Out:
# (5+2j)

# %%
str(5+2j)
# Out:
# '(5+2j)'
